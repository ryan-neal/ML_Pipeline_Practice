# %%
# download necessary NLTK data
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
nltk.download(['punkt', 'wordnet'])
import re

# import statements
import pandas as pd
# Out:
# [nltk_data] Downloading package punkt to /Users/ryanneal/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/ryanneal/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def load_data():
    df = pd.read_csv('corporate_messaging.csv', encoding='latin-1')
    df = df[(df["category:confidence"] == 1) & (df['category'] != 'Exclude')]
    X = df.text.values
    y = df.category.values
    return X, y

# %%
url_regex = ('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')

# %%
def tokenize(text):
    # get list of all urls using regex
    detected_urls = re.findall(url_regex, text)
    
    # replace each url in text string with placeholder
    for url in detected_urls:
        text = text.replace(url, "urlplaceholder")

    # tokenize text
    tokens = word_tokenize(text)
    
    # initiate lemmatizer
    lemmatizer = wordnet_lemmatizer = WordNetLemmatizer()

    # iterate through each token
    clean_tokens = []
    for tok in tokens:
        
        # lemmatize, normalize case, and remove leading/trailing white space
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens

# %%
X, y = load_data()
for message in X:
    tokens = tokenize(message)
    print(message)
    print(tokens, '\n')
# Out:
# Barclays CEO stresses the importance of regulatory and cultural reform in financial services at Brussels conference  http://t.co/Ge9Lp7hpyG
# ['barclays', 'ceo', 'stress', 'the', 'importance', 'of', 'regulatory', 'and', 'cultural', 'reform', 'in', 'financial', 'service', 'at', 'brussels', 'conference', 'urlplaceholder']
#
# Barclays announces result of Rights Issue http://t.co/LbIqqh3wwG
# ['barclays', 'announces', 'result', 'of', 'rights', 'issue', 'urlplaceholder']
#
# Barclays publishes its prospectus for its å£5.8bn Rights Issue: http://t.co/YZk24iE8G6
# ['barclays', 'publishes', 'it', 'prospectus', 'for', 'it', 'å£5.8bn', 'rights', 'issue', ':', 'urlplaceholder']
#
# Barclays Group Finance Director Chris Lucas is to step down at the end of the week due to ill health http://t.co/nkuHoAfnSD
# ['barclays', 'group', 'finance', 'director', 'chris', 'lucas', 'is', 'to', 'step', 'down', 'at', 'the', 'end', 'of', 'the', 'week', 'due', 'to', 'ill', 'health', 'urlplaceholder']
#
# Barclays announces that Irene McDermott Brown has been appointed as Group Human Resources Director http://t.co/c3fNGY6NMT
# ['barclays', 'announces', 'that', 'irene', 'mcdermott', 'brown', 'ha', 'been', 'appointed', 'a', 'group', 'human', 'resources', 'director', 'urlplaceholder']
#
# Barclays response to PRA capital shortfall exercise: http://t.co/LwsUQVFaMz
# ['barclays', 'response', 'to', 'pra', 'capital', 'shortfall', 'exercise', ':', 'urlplaceholder']
#
# Barclays sponsors #Zamynforum BBC World Service debate on globalisation, part of a series of citizenship lectures - http://t.co/5Mqcj0LIRg
# ['barclays', 'sponsor', '#', 'zamynforum', 'bbc', 'world', 'service', 'debate', 'on', 'globalisation', ',', 'part', 'of', 'a', 'series', 'of', 'citizenship', 'lecture', '-', 'urlplaceholder']
#
# Barclays has today published its response to The Salz Review, the independent report into our business practices: http://t.co/QIrl6TuAtf
# ['barclays', 'ha', 'today', 'published', 'it', 'response', 'to', 'the', 'salz', 'review', ',', 'the', 'independent', 'report', 'into', 'our', 'business', 'practice', ':', 'urlplaceholder']
#
# 59% of workers are either looking to change jobs or have applied, the highest figures recorded yet. More in our video http://t.co/JbZ2Sx8JLT
# ['59', '%', 'of', 'worker', 'are', 'either', 'looking', 'to', 'change', 'job', 'or', 'have', 'applied', ',', 'the', 'highest', 'figure', 'recorded', 'yet', '.', 'more', 'in', 'our', 'video', 'urlplaceholder']
#
# You no longer have one workforce. You have five. Want the employee benefits plan to match? Our video tells you how. http://t.co/Mxydes7LHG
# ['you', 'no', 'longer', 'have', 'one', 'workforce', '.', 'you', 'have', 'five', '.', 'want', 'the', 'employee', 'benefit', 'plan', 'to', 'match', '?', 'our', 'video', 'tell', 'you', 'how', '.', 'urlplaceholder']
#
# UK entrepreneurial activity in 2013 at a glance - Barclays and @BGF_team Entrepreneurs Index: http://t.co/8F6YStpAqS http://t.co/Uqg4l09RC9
# ['uk', 'entrepreneurial', 'activity', 'in', '2013', 'at', 'a', 'glance', '-', 'barclays', 'and', '@', 'bgf_team', 'entrepreneurs', 'index', ':', 'urlplaceholder', 'urlplaceholder']
#
# Emma Turner, Head of Client Philanthropy provides a short insight into giving. Catch her latest blog here. #charity http://t.co/5YaLwoeoSm
# ['emma', 'turner', ',', 'head', 'of', 'client', 'philanthropy', 'provides', 'a', 'short', 'insight', 'into', 'giving', '.', 'catch', 'her', 'latest', 'blog', 'here', '.', '#', 'charity', 'urlplaceholder']
#
# ...Visit us @NAPFnews 5-7 March for more workforce insights. #NAPF #pension http://t.co/eR9REnMww6 http://t.co/HCbfiJBJkB
# ['...', 'visit', 'u', '@', 'napfnews', '5-7', 'march', 'for', 'more', 'workforce', 'insight', '.', '#', 'napf', '#', 'pension', 'urlplaceholder', 'urlplaceholder']
#
# Will the chill in #emergingmarkets last a little longer as developed markets remain broadly positive? http://t.co/uiv1zY0eC0
# ['will', 'the', 'chill', 'in', '#', 'emergingmarkets', 'last', 'a', 'little', 'longer', 'a', 'developed', 'market', 'remain', 'broadly', 'positive', '?', 'urlplaceholder']
#
# Jaime Arguello examines whether 2014 is the right time to seek opportunities in #EmergingMarkets. http://t.co/4YwH59RK65
# ['jaime', 'arguello', 'examines', 'whether', '2014', 'is', 'the', 'right', 'time', 'to', 'seek', 'opportunity', 'in', '#', 'emergingmarkets', '.', 'urlplaceholder']
#
# Student of the Year Awards for Island's exceptional young people, as we proudly sponsored for the 17th consecutive yr.http://t.co/ThFeBVRcpC
# ['student', 'of', 'the', 'year', 'awards', 'for', 'island', "'s", 'exceptional', 'young', 'people', ',', 'a', 'we', 'proudly', 'sponsored', 'for', 'the', '17th', 'consecutive', 'yr.urlplaceholder']
#
# Young people at the focus  4 local charities have been awarded funding at the 2013 Barclays Community Awards event. http://t.co/KKYEizko9H
# ['young', 'people', 'at', 'the', 'focus', '4', 'local', 'charity', 'have', 'been', 'awarded', 'funding', 'at', 'the', '2013', 'barclays', 'community', 'awards', 'event', '.', 'urlplaceholder']
#
# We are delighted to have been ranked best wealth manager on social in the 2013 MyPrivateBanking report. @MPB_Research http://t.co/1JqEWdUEl1
# ['we', 'are', 'delighted', 'to', 'have', 'been', 'ranked', 'best', 'wealth', 'manager', 'on', 'social', 'in', 'the', '2013', 'myprivatebanking', 'report', '.', '@', 'mpb_research', 'urlplaceholder']
#
# Barclays &amp  @BGF_team #EntrepreneursIndex report launches on Mon, looking at levels of entrepreneurial activity in the UK &amp  Ireland.
# ['barclays', '&', 'amp', '@', 'bgf_team', '#', 'entrepreneursindex', 'report', 'launch', 'on', 'mon', ',', 'looking', 'at', 'level', 'of', 'entrepreneurial', 'activity', 'in', 'the', 'uk', '&', 'amp', 'ireland', '.']
#
# Proud to sponsor @BVCA Conference today. Lots of thought provoking content for the private equity industry. http://t.co/3quSldCkdj
# ['proud', 'to', 'sponsor', '@', 'bvca', 'conference', 'today', '.', 'lots', 'of', 'thought', 'provoking', 'content', 'for', 'the', 'private', 'equity', 'industry', '.', 'urlplaceholder']
#
# ÛÏEmployers must now address the fundamental landscape change in workforce requirements and demandsÛ: Zain Wadee http://t.co/EWnxl8e78H
# ['\x89ûïemployers', 'must', 'now', 'address', 'the', 'fundamental', 'landscape', 'change', 'in', 'workforce', 'requirement', 'and', 'demands\x89û\x9d', ':', 'zain', 'wadee', 'urlplaceholder']
#
# Gen Y: 65% seek financial education &amp  guidance says latest research. View our infographic for more details. http://t.co/Lq2539U7W1
# ['gen', 'y', ':', '65', '%', 'seek', 'financial', 'education', '&', 'amp', 'guidance', 'say', 'latest', 'research', '.', 'view', 'our', 'infographic', 'for', 'more', 'detail', '.', 'urlplaceholder']
#
# Visit us at stand 310 @eb__live  to see a new way of approaching benefits in the workplace. #EBlive2013
# ['visit', 'u', 'at', 'stand', '310', '@', 'eb__live', 'to', 'see', 'a', 'new', 'way', 'of', 'approaching', 'benefit', 'in', 'the', 'workplace', '.', '#', 'eblive2013']
#
# Why benefit strategies are failing younger workers. Are they fit for purpose? #employeeengagment http://t.co/DflYI24Muc
# ['why', 'benefit', 'strategy', 'are', 'failing', 'younger', 'worker', '.', 'are', 'they', 'fit', 'for', 'purpose', '?', '#', 'employeeengagment', 'urlplaceholder']
#
# Gen X places importance on company pension schemes  77% value this, 69% value flexible working hours finds report. http://t.co/44xL64knF0
# ['gen', 'x', 'place', 'importance', 'on', 'company', 'pension', 'scheme', '77', '%', 'value', 'this', ',', '69', '%', 'value', 'flexible', 'working', 'hour', 'find', 'report', '.', 'urlplaceholder']
#
# Baby Boomers: Least demanding generation, 71% value their company pension scheme &amp  57% career development says report http://t.co/uLfgPZ14hX
# ['baby', 'boomers', ':', 'least', 'demanding', 'generation', ',', '71', '%', 'value', 'their', 'company', 'pension', 'scheme', '&', 'amp', '57', '%', 'career', 'development', 'say', 'report', 'urlplaceholder']
#
# Latest research finds over 90% of employees from all generations have no access to work-based financial guidance. http://t.co/SuyTDLPt8f
# ['latest', 'research', 'find', 'over', '90', '%', 'of', 'employee', 'from', 'all', 'generation', 'have', 'no', 'access', 'to', 'work-based', 'financial', 'guidance', '.', 'urlplaceholder']
#
# Employee benefits failing to meet expectations of todayÛªs multigenerational workforce. #employeeengagment http://t.co/CE5JmPcC2t
# ['employee', 'benefit', 'failing', 'to', 'meet', 'expectation', 'of', 'today\x89ûªs', 'multigenerational', 'workforce', '.', '#', 'employeeengagment', 'urlplaceholder']
#
# #Barclays will be @eb__live join us &amp  discover a new way to approach workplace benefits. Register to join #EBLive2013 http://t.co/ErmGCX2RGv
# ['#', 'barclays', 'will', 'be', '@', 'eb__live', 'join', 'u', '&', 'amp', 'discover', 'a', 'new', 'way', 'to', 'approach', 'workplace', 'benefit', '.', 'register', 'to', 'join', '#', 'eblive2013', 'urlplaceholder']
#
# Does your benefits package meet needs of younger workers? New Barclays report suggests employers need to adapt. http://t.co/tgJvgTVlzM
# ['does', 'your', 'benefit', 'package', 'meet', 'need', 'of', 'younger', 'worker', '?', 'new', 'barclays', 'report', 'suggests', 'employer', 'need', 'to', 'adapt', '.', 'urlplaceholder']
#
# 65% of Gen Y employees would value financial education or guidance in the workplace  83% say it's unvailable to them. http://t.co/w9EnRdi25p
# ['65', '%', 'of', 'gen', 'y', 'employee', 'would', 'value', 'financial', 'education', 'or', 'guidance', 'in', 'the', 'workplace', '83', '%', 'say', 'it', "'s", 'unvailable', 'to', 'them', '.', 'urlplaceholder']
#
# One-size-fits-all employee benefits fail to meet needs of younger employees in workplace: Says new Barclays research. http://t.co/iydcirSpeu
# ['one-size-fits-all', 'employee', 'benefit', 'fail', 'to', 'meet', 'need', 'of', 'younger', 'employee', 'in', 'workplace', ':', 'says', 'new', 'barclays', 'research', '.', 'urlplaceholder']
#
# Do you know the simple safety checks to make on your bike? Check out our video to find out more. http://t.co/wLBJaDxSmT
# ['do', 'you', 'know', 'the', 'simple', 'safety', 'check', 'to', 'make', 'on', 'your', 'bike', '?', 'check', 'out', 'our', 'video', 'to', 'find', 'out', 'more', '.', 'urlplaceholder']
#
# Entrepreneurial activity in the industrial sector up by 30%, shows our latest Entrepreneurs Index. http://t.co/lJh4GmaSLs
# ['entrepreneurial', 'activity', 'in', 'the', 'industrial', 'sector', 'up', 'by', '30', '%', ',', 'show', 'our', 'latest', 'entrepreneurs', 'index', '.', 'urlplaceholder']
#
# Û÷Get on your bikeÛª - the benefits of cycling from health &amp  freedom through to environment &amp  cost.Watch the video here http://t.co/MhoQFPOw
# ['\x89û÷get', 'on', 'your', 'bike\x89ûª', '-', 'the', 'benefit', 'of', 'cycling', 'from', 'health', '&', 'amp', 'freedom', 'through', 'to', 'environment', '&', 'amp', 'cost.watch', 'the', 'video', 'here', 'urlplaceholder']
#
# Entrepreneurial activity on the up in last six months of 2012 http://t.co/Sxfx9xDl94 Barclays Entrepreneurs Index in City AM
# ['entrepreneurial', 'activity', 'on', 'the', 'up', 'in', 'last', 'six', 'month', 'of', '2012', 'urlplaceholder', 'barclays', 'entrepreneurs', 'index', 'in', 'city', 'am']
#
# Resurgence in entrepreneurial activity across UK &amp  Ireland as shareholder changes increase http://t.co/elANBEsyIS
# ['resurgence', 'in', 'entrepreneurial', 'activity', 'across', 'uk', '&', 'amp', 'ireland', 'a', 'shareholder', 'change', 'increase', 'urlplaceholder']
#
# Our 2nd report in our Entrepreneurs Index series shows resurgence in entrepreneurial activity from H2 2011 to H2 2012 http://t.co/RXSZsHqtMq
# ['our', '2nd', 'report', 'in', 'our', 'entrepreneurs', 'index', 'series', 'show', 'resurgence', 'in', 'entrepreneurial', 'activity', 'from', 'h2', '2011', 'to', 'h2', '2012', 'urlplaceholder']
#
# Barclays Wealth tops Customer Service Awards. http://t.co/muPHJ7Cg
# ['barclays', 'wealth', 'top', 'customer', 'service', 'awards', '.', 'urlplaceholder']
#
# Helping you make sense of Philanthropy... http://t.co/BlFchVO2
# ['helping', 'you', 'make', 'sense', 'of', 'philanthropy', '...', 'urlplaceholder']
#
# Check out the video highlights of the exclusive #OpenOutcry event @GregBDavies http://t.co/cJ03VkcR
# ['check', 'out', 'the', 'video', 'highlight', 'of', 'the', 'exclusive', '#', 'openoutcry', 'event', '@', 'gregbdavies', 'urlplaceholder']
#
# Take a look at the highlights of the exclusive event #OpenOutcry the reality opera @GregBDavies http://t.co/U9rM2z18
# ['take', 'a', 'look', 'at', 'the', 'highlight', 'of', 'the', 'exclusive', 'event', '#', 'openoutcry', 'the', 'reality', 'opera', '@', 'gregbdavies', 'urlplaceholder']
#
# Two STEP student awards for Barclays Wealth and Investment Management. http://t.co/DduRNDz7
# ['two', 'step', 'student', 'award', 'for', 'barclays', 'wealth', 'and', 'investment', 'management', '.', 'urlplaceholder']
#
# Barclays Wealth and Investment Management sponsors Isle of Man Student of the Year awards. http://t.co/5ZI7shpM
# ['barclays', 'wealth', 'and', 'investment', 'management', 'sponsor', 'isle', 'of', 'man', 'student', 'of', 'the', 'year', 'award', '.', 'urlplaceholder']
#
# Barclays Wealth and Investment Management sponsors IOD Seminar on the Director's role in managing risk. http://t.co/nXWDM1kV
# ['barclays', 'wealth', 'and', 'investment', 'management', 'sponsor', 'iod', 'seminar', 'on', 'the', 'director', "'s", 'role', 'in', 'managing', 'risk', '.', 'urlplaceholder']
#
# Investors' biggest concerns focus on the developed world ÛÒ the euro's existential... http://t.co/sFVKc7l0
# ['investors', "'", 'biggest', 'concern', 'focus', 'on', 'the', 'developed', 'world', '\x89ûò', 'the', 'euro', "'s", 'existential', '...', 'urlplaceholder']
#
# Our Behavioural Finance Specialists have developed a unique proprietary... http://t.co/TZ0lUIv3
# ['our', 'behavioural', 'finance', 'specialists', 'have', 'developed', 'a', 'unique', 'proprietary', '...', 'urlplaceholder']
#
# RT WSJ Wealth Report Do the Rich Work Less as Their Taxes Increase? http://t.co/3tKQxy6d
# ['rt', 'wsj', 'wealth', 'report', 'do', 'the', 'rich', 'work', 'less', 'a', 'their', 'taxes', 'increase', '?', 'urlplaceholder']
#
# RT WSJ Wealth Report Did The Rich Get Rich From Hard Work or ?Connections? ? http://t.co/wwKijiMZ
# ['rt', 'wsj', 'wealth', 'report', 'did', 'the', 'rich', 'get', 'rich', 'from', 'hard', 'work', 'or', '?', 'connections', '?', '?', 'urlplaceholder']
#
# FT Eurozone Blog: Africa rebuffs CameronÛªs gay rights gambit http://t.co/e7VTs4fI
# ['ft', 'eurozone', 'blog', ':', 'africa', 'rebuff', 'cameron\x89ûªs', 'gay', 'right', 'gambit', 'urlplaceholder']
#
# Over a third of global wealthy do not trust the next generation to safeguard their wealth http://t.co/PHTM2BO2
# ['over', 'a', 'third', 'of', 'global', 'wealthy', 'do', 'not', 'trust', 'the', 'next', 'generation', 'to', 'safeguard', 'their', 'wealth', 'urlplaceholder']
#
# Barclays Wealth Blog Communication breakdown? - Our usual stoicism has been tested somewhat these last two weeks. We... http://t.co/xpzfQPsU
# ['barclays', 'wealth', 'blog', 'communication', 'breakdown', '?', '-', 'our', 'usual', 'stoicism', 'ha', 'been', 'tested', 'somewhat', 'these', 'last', 'two', 'week', '.', 'we', '...', 'urlplaceholder']
#
# Barclays Wealth backs Student of the Year awards. http://ow.ly/6Qpkc
# ['barclays', 'wealth', 'back', 'student', 'of', 'the', 'year', 'award', '.', 'urlplaceholder']
#
# RT WSJ Wealth Report Steve Jobs Can Still Become a Great Philanthropist http://t.co/l3jjmAF4
# ['rt', 'wsj', 'wealth', 'report', 'steve', 'jobs', 'can', 'still', 'become', 'a', 'great', 'philanthropist', 'urlplaceholder']
#
# Spain to Sell Government Bonds Amid Systemic-Risk Threat. http://ow.ly/6vb21
# ['spain', 'to', 'sell', 'government', 'bonds', 'amid', 'systemic-risk', 'threat', '.', 'urlplaceholder']
#
# RT WSJ Wealth Report Government Defines Who is 'Family' for the Rich http://ow.ly/1dZvNM
# ['rt', 'wsj', 'wealth', 'report', 'government', 'defines', 'who', 'is', "'family", "'", 'for', 'the', 'rich', 'urlplaceholder']
#
# RT WSJ Wealth Report How to Marry Rich in China - A new school called in Beijing called the Moral Education Center f... http://ow.ly/1dRQ4M
# ['rt', 'wsj', 'wealth', 'report', 'how', 'to', 'marry', 'rich', 'in', 'china', '-', 'a', 'new', 'school', 'called', 'in', 'beijing', 'called', 'the', 'moral', 'education', 'center', 'f', '...', 'urlplaceholder']
#
# Barclays WealthÛªs Global Client Service Centres won UK Customer Experience Award in Financial Services at 2011 UK Customer Experience Awards
# ['barclays', 'wealth\x89ûªs', 'global', 'client', 'service', 'centres', 'won', 'uk', 'customer', 'experience', 'award', 'in', 'financial', 'services', 'at', '2011', 'uk', 'customer', 'experience', 'awards']
#
# Barclays Wealth was named Wealth Manager of the Year for the third consecutive year at the 2011 Global Investor Awards. http://owl.li/5ClLv
# ['barclays', 'wealth', 'wa', 'named', 'wealth', 'manager', 'of', 'the', 'year', 'for', 'the', 'third', 'consecutive', 'year', 'at', 'the', '2011', 'global', 'investor', 'awards', '.', 'urlplaceholder']
#
# Barclays Wealth continues to recommend developed equities, despite volatile markets. http://owl.li/5yEqr
# ['barclays', 'wealth', 'continues', 'to', 'recommend', 'developed', 'equity', ',', 'despite', 'volatile', 'market', '.', 'urlplaceholder']
#
# Barclays Wealth partners with Museum of Liverpool for exhibition sponsorship. http://owl.li/56MzX
# ['barclays', 'wealth', 'partner', 'with', 'museum', 'of', 'liverpool', 'for', 'exhibition', 'sponsorship', '.', 'urlplaceholder']
#
# RT WSJ Wealth Report The Rich Use the Web Mostly for Money, Food & Porn http://ow.ly/1cS37H
# ['rt', 'wsj', 'wealth', 'report', 'the', 'rich', 'use', 'the', 'web', 'mostly', 'for', 'money', ',', 'food', '&', 'porn', 'urlplaceholder']
#
# Foundations and endowments need to reconsider their investment approach in a low return environment. http://ow.ly/3nfch
# ['foundations', 'and', 'endowment', 'need', 'to', 'reconsider', 'their', 'investment', 'approach', 'in', 'a', 'low', 'return', 'environment', '.', 'urlplaceholder']
#
# The Global Culture of Philanthropy and Attitudes to Giving. http://ow.ly/3lURy
# ['the', 'global', 'culture', 'of', 'philanthropy', 'and', 'attitudes', 'to', 'giving', '.', 'urlplaceholder']
#
# RT @WSJWealthReport Are Rich Donors Ruining Higher Education? http://ow.ly/18ZjxN
# ['rt', '@', 'wsjwealthreport', 'are', 'rich', 'donors', 'ruining', 'higher', 'education', '?', 'urlplaceholder']
#
# Barclays Wealth supports 'Women of The Year Awards'. http://ow.ly/2sknz
# ['barclays', 'wealth', 'support', "'women", 'of', 'the', 'year', 'awards', "'", '.', 'urlplaceholder']
#
# RT @BarclaysStock: Have a look at the top ten most popular stocks in our Top Ten Trades from the last week http://bit.ly/cpdycq
# ['rt', '@', 'barclaysstock', ':', 'have', 'a', 'look', 'at', 'the', 'top', 'ten', 'most', 'popular', 'stock', 'in', 'our', 'top', 'ten', 'trades', 'from', 'the', 'last', 'week', 'urlplaceholder']
#
# RT @BarclaysStock: Investment ViewPoint: Comment looks at activity driving market sentiment, at home and away. http://tinyurl.com/34e9pv2
# ['rt', '@', 'barclaysstock', ':', 'investment', 'viewpoint', ':', 'comment', 'look', 'at', 'activity', 'driving', 'market', 'sentiment', ',', 'at', 'home', 'and', 'away', '.', 'urlplaceholder']
#
# Hard-working wealth, holistic wealth or co-operative wealth? The three themes for the future. http://ow.ly/1QB6Y
# ['hard-working', 'wealth', ',', 'holistic', 'wealth', 'or', 'co-operative', 'wealth', '?', 'the', 'three', 'theme', 'for', 'the', 'future', '.', 'urlplaceholder']
#
# The emergence of the active investor - managing financial affairs is a daily routine for many. http://ow.ly/1QwTS
# ['the', 'emergence', 'of', 'the', 'active', 'investor', '-', 'managing', 'financial', 'affair', 'is', 'a', 'daily', 'routine', 'for', 'many', '.', 'urlplaceholder']
#
# Barclays Wealth's Aaron Gurwitz is urging clients to stick with US equities, particularly those of developed economies. http://su.pr/17UUZi
# ['barclays', 'wealth', "'s", 'aaron', 'gurwitz', 'is', 'urging', 'client', 'to', 'stick', 'with', 'us', 'equity', ',', 'particularly', 'those', 'of', 'developed', 'economy', '.', 'urlplaceholder']
#
# Barclays Wealth Gives Groudle Glen Railway A Spring Spruce-Up. Staff volunteers from Barclays Wealth have been working...http://su.pr/1se57I
# ['barclays', 'wealth', 'gives', 'groudle', 'glen', 'railway', 'a', 'spring', 'spruce-up', '.', 'staff', 'volunteer', 'from', 'barclays', 'wealth', 'have', 'been', 'working', '...', 'urlplaceholder']
#
# RT @bbcbusiness UK manufacturing activity grew at its fastest for 15 years in Mar, according to closely-watched survey http://bit.ly/axwoCE
# ['rt', '@', 'bbcbusiness', 'uk', 'manufacturing', 'activity', 'grew', 'at', 'it', 'fastest', 'for', '15', 'year', 'in', 'mar', ',', 'according', 'to', 'closely-watched', 'survey', 'urlplaceholder']
#
# RT @WSJWealthReport Millionaire Says Money Û÷Prevents HappinessÛª http://ow.ly/16xhzW
# ['rt', '@', 'wsjwealthreport', 'millionaire', 'says', 'money', '\x89û÷prevents', 'happiness\x89ûª', 'urlplaceholder']
#
# RT @WSJWealthReport AmericaÛªs Top 50 Philanthropists Gave Less in 2009 http://ow.ly/16wPkH
# ['rt', '@', 'wsjwealthreport', 'america\x89ûªs', 'top', '50', 'philanthropists', 'gave', 'less', 'in', '2009', 'urlplaceholder']
#
# Barclays Wealth sponsorship of Spectator online Book Club - Barclays Wealth sponsors Spectator's literary online in... http://ow.ly/16f9D2
# ['barclays', 'wealth', 'sponsorship', 'of', 'spectator', 'online', 'book', 'club', '-', 'barclays', 'wealth', 'sponsor', 'spectator', "'s", 'literary', 'online', 'in', '...', 'urlplaceholder']
#
# Matt Brady on #philanthropy: Charitable Giving In Tough Times http://su.pr/7qQvp1
# ['matt', 'brady', 'on', '#', 'philanthropy', ':', 'charitable', 'giving', 'in', 'tough', 'times', 'urlplaceholder']
#
# Barclays Wealth looks at the current state of Guernsey's finance community http://ow.ly/Djqj
# ['barclays', 'wealth', 'look', 'at', 'the', 'current', 'state', 'of', 'guernsey', "'s", 'finance', 'community', 'urlplaceholder']
#
# Barclays Wealth Hosts Excellence Awards in Isle of Man http://ow.ly/D7Mr
# ['barclays', 'wealth', 'hosts', 'excellence', 'awards', 'in', 'isle', 'of', 'man', 'urlplaceholder']
#
# 'Philanthropology: The Evolution of Giving' - Barclays Wealth identifies the characteristics of wealthy philanthropists. http://su.pr/9L1oeg
# ["'philanthropology", ':', 'the', 'evolution', 'of', 'giving', "'", '-', 'barclays', 'wealth', 'identifies', 'the', 'characteristic', 'of', 'wealthy', 'philanthropist', '.', 'urlplaceholder']
#
# Record number of charities enter the 2009 Barclays Wealth Community Awards in Jersey, Channel Islands http://ow.ly/CZIy
# ['record', 'number', 'of', 'charity', 'enter', 'the', '2009', 'barclays', 'wealth', 'community', 'awards', 'in', 'jersey', ',', 'channel', 'islands', 'urlplaceholder']
#
# RT @WSJWealthReport Does the Gates Foundation Need a $500 Million Complex? http://ow.ly/1625QH
# ['rt', '@', 'wsjwealthreport', 'does', 'the', 'gates', 'foundation', 'need', 'a', '$', '500', 'million', 'complex', '?', 'urlplaceholder']
#
# BW  wins Best Leadership Team in Global Private Banking in Geneva sponsored by The Banker & Professional Wealth Management magazines
# ['bw', 'win', 'best', 'leadership', 'team', 'in', 'global', 'private', 'banking', 'in', 'geneva', 'sponsored', 'by', 'the', 'banker', '&', 'professional', 'wealth', 'management', 'magazine']
#
# RT @WSJWealthReport Charitable Gifts to Drop 9% in 2009 - The Chronicle of Philanthropy says giving to the 400 larg... http://ow.ly/15XDQ3
# ['rt', '@', 'wsjwealthreport', 'charitable', 'gifts', 'to', 'drop', '9', '%', 'in', '2009', '-', 'the', 'chronicle', 'of', 'philanthropy', 'say', 'giving', 'to', 'the', '400', 'larg', '...', 'urlplaceholder']
#
# RT @WSJEconomy: Euro Zone Posts Trade Deficit http://bit.ly/sjlI2
# ['rt', '@', 'wsjeconomy', ':', 'euro', 'zone', 'posts', 'trade', 'deficit', 'urlplaceholder']
#
# AN AMBITIOUS younger breed of wealthy #philanthropists, known as  go givers  are emerging despite the recession http://su.pr/4ekTce
# ['an', 'ambitious', 'younger', 'breed', 'of', 'wealthy', '#', 'philanthropist', ',', 'known', 'a', 'go', 'giver', 'are', 'emerging', 'despite', 'the', 'recession', 'urlplaceholder']
#
# Isle of Man News: Barclays Wealth launches student of the year awards http://su.pr/7yGDT5
# ['isle', 'of', 'man', 'news', ':', 'barclays', 'wealth', 'launch', 'student', 'of', 'the', 'year', 'award', 'urlplaceholder']
#
# WealthBriefing: Barclays Wealth bullish on philanthropy http://bit.ly/aOLUm
# ['wealthbriefing', ':', 'barclays', 'wealth', 'bullish', 'on', 'philanthropy', 'urlplaceholder']
#
# See our daily research showing recent market developments http://bit.ly/BbOjj
# ['see', 'our', 'daily', 'research', 'showing', 'recent', 'market', 'development', 'urlplaceholder']
#
# Five days to go till the Barclays #JerseyBoatShow. We return with a weekend packed with energy, events and activity. http://t.co/U8YyxdwCv5
# ['five', 'day', 'to', 'go', 'till', 'the', 'barclays', '#', 'jerseyboatshow', '.', 'we', 'return', 'with', 'a', 'weekend', 'packed', 'with', 'energy', ',', 'event', 'and', 'activity', '.', 'urlplaceholder']
#
# The Maturist: Concerned about pensions &amp  savings. Research shows their values have shaped todayÛªs workplace. http://t.co/ZqrjJ8hyYm
# ['the', 'maturist', ':', 'concerned', 'about', 'pension', '&', 'amp', 'saving', '.', 'research', 'show', 'their', 'value', 'have', 'shaped', 'today\x89ûªs', 'workplace', '.', 'urlplaceholder']
#
# Developed countries display higher levels of uncertainty in next generation looking after wealth: Australia 59%, US 61% http://t.co/r5r5Ib7o
# ['developed', 'country', 'display', 'higher', 'level', 'of', 'uncertainty', 'in', 'next', 'generation', 'looking', 'after', 'wealth', ':', 'australia', '59', '%', ',', 'us', '61', '%', 'urlplaceholder']
#
# Entrepreneurship responsible for most UK wealth ÛÒ Barclays Wealth Insights. http://t.co/fZkE1ReDaR
# ['entrepreneurship', 'responsible', 'for', 'most', 'uk', 'wealth', '\x89ûò', 'barclays', 'wealth', 'insights', '.', 'urlplaceholder']
#
# Overcoming the cost of being humanÛ_ http://t.co/LhNC2PldG1
# ['overcoming', 'the', 'cost', 'of', 'being', 'human\x89û_', 'urlplaceholder']
#
# Entrepreneurial activity in tech sector up by 40% on 201 shows the 2nd report in Barclays Entrepreneurs Index series http://t.co/8rWMXFOhPu
# ['entrepreneurial', 'activity', 'in', 'tech', 'sector', 'up', 'by', '40', '%', 'on', '201', 'show', 'the', '2nd', 'report', 'in', 'barclays', 'entrepreneurs', 'index', 'series', 'urlplaceholder']
#
# Gay, Lesbian Workers Increasingly At Home In the City http://ow.ly/18aWf
# ['gay', ',', 'lesbian', 'workers', 'increasingly', 'at', 'home', 'in', 'the', 'city', 'urlplaceholder']
#
# The economic recovery ÛÏis fairly mediocre by historical standards, says Michael Dicks http://ow.ly/UcvA
# ['the', 'economic', 'recovery', '\x89ûïis', 'fairly', 'mediocre', 'by', 'historical', 'standard', ',', 'say', 'michael', 'dicks', 'urlplaceholder']
#
# RT @BarclaysStock: most popular trades from last week. Top Ten buys and sells http://bit.ly/6BQNBV
# ['rt', '@', 'barclaysstock', ':', 'most', 'popular', 'trade', 'from', 'last', 'week', '.', 'top', 'ten', 'buy', 'and', 'sell', 'urlplaceholder']
#
# RT @BarclaysStock: FOMC left rates unchanged following meeting but said economic activity had picked up following the severe downturn
# ['rt', '@', 'barclaysstock', ':', 'fomc', 'left', 'rate', 'unchanged', 'following', 'meeting', 'but', 'said', 'economic', 'activity', 'had', 'picked', 'up', 'following', 'the', 'severe', 'downturn']
#
# Latest research shows Gen Z values flexible working &amp  access to career development. Are said to be socially aware. http://t.co/PivSYEACdw
# ['latest', 'research', 'show', 'gen', 'z', 'value', 'flexible', 'working', '&', 'amp', 'access', 'to', 'career', 'development', '.', 'are', 'said', 'to', 'be', 'socially', 'aware', '.', 'urlplaceholder']
#
# Barclays are proud sponsors of Legal Week Private Client Forum: The evolution of wealth taking place 31/10 - 2/11. http://t.co/NMfnjZrG8o
# ['barclays', 'are', 'proud', 'sponsor', 'of', 'legal', 'week', 'private', 'client', 'forum', ':', 'the', 'evolution', 'of', 'wealth', 'taking', 'place', '31/10', '-', '2/11', '.', 'urlplaceholder']
#
# RT @WSJWealthReport Wealthy Give More Overseas, Less to Education, Religion http://ow.ly/17FYeA
# ['rt', '@', 'wsjwealthreport', 'wealthy', 'give', 'more', 'overseas', ',', 'less', 'to', 'education', ',', 'religion', 'urlplaceholder']
#
# Aaron Gurwitz, head of investment strategy, is fairly optimistic that the global economic recovery will stay on track http://ow.ly/1A2rK
# ['aaron', 'gurwitz', ',', 'head', 'of', 'investment', 'strategy', ',', 'is', 'fairly', 'optimistic', 'that', 'the', 'global', 'economic', 'recovery', 'will', 'stay', 'on', 'track', 'urlplaceholder']
#
# RT @WSJWealthReport A Stock Exchange for Charities - One of the biggest problems for philanthropists is finding the... http://ow.ly/164iDD
# ['rt', '@', 'wsjwealthreport', 'a', 'stock', 'exchange', 'for', 'charities', '-', 'one', 'of', 'the', 'biggest', 'problem', 'for', 'philanthropist', 'is', 'finding', 'the', '...', 'urlplaceholder']
#
# RT BarclaysStockTrade RBS covered warrants for å£1 for a limited time only http://su.pr/AjFlB9
# ['rt', 'barclaysstocktrade', 'rbs', 'covered', 'warrant', 'for', 'å£1', 'for', 'a', 'limited', 'time', 'only', 'urlplaceholder']
#
# #HayFestival award-winning folk #ElizaCarthyBand playing tonight in #BarclaysWealth Pavilion at 20:00 #hay - http://owl.li/58Hn9
# ['#', 'hayfestival', 'award-winning', 'folk', '#', 'elizacarthyband', 'playing', 'tonight', 'in', '#', 'barclayswealth', 'pavilion', 'at', '20:00', '#', 'hay', '-', 'urlplaceholder']
#
# The Luxury Network marketing group launches in the UAE http://ow.ly/yydb
# ['the', 'luxury', 'network', 'marketing', 'group', 'launch', 'in', 'the', 'uae', 'urlplaceholder']
#
# RT WSJ Wealth Report Is It Fair to Call Romney a 'Silver Spoon?' http://t.co/3CNv9VrM
# ['rt', 'wsj', 'wealth', 'report', 'is', 'it', 'fair', 'to', 'call', 'romney', 'a', "'silver", 'spoon', '?', "'", 'urlplaceholder']
#
# #HayFestival Reading of children? classic Good Night Mr Tom in #BarclaysWealth Pavilion today #hay - http://owl.li/58Hna
# ['#', 'hayfestival', 'reading', 'of', 'child', '?', 'classic', 'good', 'night', 'mr', 'tom', 'in', '#', 'barclayswealth', 'pavilion', 'today', '#', 'hay', '-', 'urlplaceholder']
#
# Barclays Wealth wins 'Most Integrated Consumer Campaign' at recent Marketing Effectiveness Awards.
# ['barclays', 'wealth', 'win', "'most", 'integrated', 'consumer', 'campaign', "'", 'at', 'recent', 'marketing', 'effectiveness', 'awards', '.']
#
# RT @FT: UK public finances suffer as tax revenues tumble: Government borrowing rises to å£77.3bn in the first six months.http://bit.ly/1Q1lnb
# ['rt', '@', 'ft', ':', 'uk', 'public', 'finance', 'suffer', 'a', 'tax', 'revenue', 'tumble', ':', 'government', 'borrowing', 'rise', 'to', 'å£77.3bn', 'in', 'the', 'first', 'six', 'months.urlplaceholder']
#
# Isle of Man News: Barclays Wealth supports environmental and social awareness programme http://bit.ly/iEHqr
# ['isle', 'of', 'man', 'news', ':', 'barclays', 'wealth', 'support', 'environmental', 'and', 'social', 'awareness', 'programme', 'urlplaceholder']
#
# Derek White: Û÷We are still learning, understanding and evolving how to engage and support the start-up communityÛª. #SeedcampLive
# ['derek', 'white', ':', '\x89û÷we', 'are', 'still', 'learning', ',', 'understanding', 'and', 'evolving', 'how', 'to', 'engage', 'and', 'support', 'the', 'start-up', 'community\x89ûª', '.', '#', 'seedcamplive']
#
# Barclays Wealth and Investment Management win at the European Contact Centre and Customer Service Awards
# ['barclays', 'wealth', 'and', 'investment', 'management', 'win', 'at', 'the', 'european', 'contact', 'centre', 'and', 'customer', 'service', 'awards']
#
# Global wealthy advise children to learn languages for success. 68% say English is vital  Britons say Chinese. http://t.co/6gDzSVOi
# ['global', 'wealthy', 'advise', 'child', 'to', 'learn', 'language', 'for', 'success', '.', '68', '%', 'say', 'english', 'is', 'vital', 'britons', 'say', 'chinese', '.', 'urlplaceholder']
#
# Isle of Man: Local school children have been 'showing racism the red card' with the help of three former professional footballers and...
# ['isle', 'of', 'man', ':', 'local', 'school', 'child', 'have', 'been', "'showing", 'racism', 'the', 'red', 'card', "'", 'with', 'the', 'help', 'of', 'three', 'former', 'professional', 'footballer', 'and', '...']
#
# New report highlights 100bn impact of major social issues and emphasises importance of early intervention http://t.co/AkskkGNh
# ['new', 'report', 'highlight', '100bn', 'impact', 'of', 'major', 'social', 'issue', 'and', 'emphasis', 'importance', 'of', 'early', 'intervention', 'urlplaceholder']
#
# Barclays research shows 4 attitudes to financial planning, which does your workforce have? http://t.co/jmhLI5PsJP http://t.co/niyWLlNL0V
# ['barclays', 'research', 'show', '4', 'attitude', 'to', 'financial', 'planning', ',', 'which', 'doe', 'your', 'workforce', 'have', '?', 'urlplaceholder', 'urlplaceholder']
#
# RT WSJ Wealth Report Is Government Behind the Rising Fortunes of the Rich? http://ow.ly/1caz9c
# ['rt', 'wsj', 'wealth', 'report', 'is', 'government', 'behind', 'the', 'rising', 'fortunes', 'of', 'the', 'rich', '?', 'urlplaceholder']
#
# Barclays Wealth wins 'Best Overall Private Bank in the UK' at the Euromoney Private Banking Awards.
# ['barclays', 'wealth', 'win', "'best", 'overall', 'private', 'bank', 'in', 'the', 'uk', "'", 'at', 'the', 'euromoney', 'private', 'banking', 'awards', '.']
#
# The moment you've been waiting for is here, 7 awards to be won. We will be presenting 'Outstanding Achievement' and 'Ones to Watch'.
# ['the', 'moment', 'you', "'ve", 'been', 'waiting', 'for', 'is', 'here', ',', '7', 'award', 'to', 'be', 'won', '.', 'we', 'will', 'be', 'presenting', "'outstanding", 'achievement', "'", 'and', "'ones", 'to', 'watch', "'", '.']
#
# As the Q&amp A's come to an end we look forward to the awards ceremony later this evening, stay tuned and good luck to all the nominees.
# ['as', 'the', 'q', '&', 'amp', 'a', "'s", 'come', 'to', 'an', 'end', 'we', 'look', 'forward', 'to', 'the', 'award', 'ceremony', 'later', 'this', 'evening', ',', 'stay', 'tuned', 'and', 'good', 'luck', 'to', 'all', 'the', 'nominee', '.']
#
# Guests and speakers at today's event are at the forefront of UK entrepreneurial activity. Great to be part of it. #FastTrack100 #SME
# ['guests', 'and', 'speaker', 'at', 'today', "'s", 'event', 'are', 'at', 'the', 'forefront', 'of', 'uk', 'entrepreneurial', 'activity', '.', 'great', 'to', 'be', 'part', 'of', 'it', '.', '#', 'fasttrack100', '#', 'sme']
#
# Designers and clients lose time due to the manual feedback loop. @conceptbox enables sharing and collaboration in real-time. #SeedcampLive
# ['designers', 'and', 'client', 'lose', 'time', 'due', 'to', 'the', 'manual', 'feedback', 'loop', '.', '@', 'conceptbox', 'enables', 'sharing', 'and', 'collaboration', 'in', 'real-time', '.', '#', 'seedcamplive']
#
# ÛÏMeasure buyer activity and see who is most engagedÛ, says CEO of @BuyerDeck @Geraldvdp. #SeedcampLive
# ['\x89ûïmeasure', 'buyer', 'activity', 'and', 'see', 'who', 'is', 'most', 'engaged\x89û\x9d', ',', 'say', 'ceo', 'of', '@', 'buyerdeck', '@', 'geraldvdp', '.', '#', 'seedcamplive']
#
# We are proud to sponsor Legal Week Private Client Forum 2013, coming soon at Villa dÛªEste, Lake Como, 31 Oct ÛÒ 2 Nov. http://t.co/PIEqG9KqE4
# ['we', 'are', 'proud', 'to', 'sponsor', 'legal', 'week', 'private', 'client', 'forum', '2013', ',', 'coming', 'soon', 'at', 'villa', 'd\x89ûªeste', ',', 'lake', 'como', ',', '31', 'oct', '\x89ûò', '2', 'nov.', 'urlplaceholder']
#
# Kevin Gardiner explores the potential impact of the US government shutdown on economic growth. #debtceiling http://t.co/L0r9mXKIwD
# ['kevin', 'gardiner', 'explores', 'the', 'potential', 'impact', 'of', 'the', 'us', 'government', 'shutdown', 'on', 'economic', 'growth', '.', '#', 'debtceiling', 'urlplaceholder']
#
# How to handle your banking 24/7, no matter where you are. Watch our video to find out more. Conditions apply. http://t.co/jMAfibo9iS
# ['how', 'to', 'handle', 'your', 'banking', '24/7', ',', 'no', 'matter', 'where', 'you', 'are', '.', 'watch', 'our', 'video', 'to', 'find', 'out', 'more', '.', 'conditions', 'apply', '.', 'urlplaceholder']
#
# Inheritors feel stronger responsibility for philanthropy than entrepreneurs. Wealth Insights Volume 17: Origins and Legacy...
# ['inheritors', 'feel', 'stronger', 'responsibility', 'for', 'philanthropy', 'than', 'entrepreneur', '.', 'wealth', 'insights', 'volume', '17', ':', 'origins', 'and', 'legacy', '...']
#
# 'Entrepreneurs and business owners taking an active role in philanthropy: The Changing Order of Wealth Creation. http://t.co/ELS0JkY2tn
# ["'entrepreneurs", 'and', 'business', 'owner', 'taking', 'an', 'active', 'role', 'in', 'philanthropy', ':', 'the', 'changing', 'order', 'of', 'wealth', 'creation', '.', 'urlplaceholder']
#
# Wealth &amp  Investment Management wins Wealth Manager of the Year award #GlobalInvestorAwards http://t.co/6z8N3xZg3b
# ['wealth', '&', 'amp', 'investment', 'management', 'win', 'wealth', 'manager', 'of', 'the', 'year', 'award', '#', 'globalinvestorawards', 'urlplaceholder']
#
# The Investment Philosophy campaign wins at the Wealth briefing European Awards 2013. Read more about Investment Philosophy....
# ['the', 'investment', 'philosophy', 'campaign', 'win', 'at', 'the', 'wealth', 'briefing', 'european', 'awards', '2013', '.', 'read', 'more', 'about', 'investment', 'philosophy', '....']
#
# #BarclaysJBS are sponsoring WetWheels charity @jerseyboatshow come and show your support http://t.co/yvir0lqutf #BarclaysDuck
# ['#', 'barclaysjbs', 'are', 'sponsoring', 'wetwheels', 'charity', '@', 'jerseyboatshow', 'come', 'and', 'show', 'your', 'support', 'urlplaceholder', '#', 'barclaysduck']
#
# RT WSJ Wealth Report Do the Wealthy Work Harder Than the Rest? http://t.co/vgkphpTu
# ['rt', 'wsj', 'wealth', 'report', 'do', 'the', 'wealthy', 'work', 'harder', 'than', 'the', 'rest', '?', 'urlplaceholder']
#
# Barclays Wealth Guernsey collects two Euromoney Awards. http://t.co/1ai5Cbou
# ['barclays', 'wealth', 'guernsey', 'collect', 'two', 'euromoney', 'awards', '.', 'urlplaceholder']
#
# RT WSJ Wealth Report Tax Philanthropists: The Rich Who Give to the Government http://t.co/muUUbZ37
# ['rt', 'wsj', 'wealth', 'report', 'tax', 'philanthropists', ':', 'the', 'rich', 'who', 'give', 'to', 'the', 'government', 'urlplaceholder']
#
# Philanthropists put a price on good deeds http://t.co/GBcdAl1z
# ['philanthropists', 'put', 'a', 'price', 'on', 'good', 'deed', 'urlplaceholder']
#
# Early-stage preventative approaches can cost a fifth of current social support. Read our latest report on philanthropy. http://t.co/tmuP6Rqc
# ['early-stage', 'preventative', 'approach', 'can', 'cost', 'a', 'fifth', 'of', 'current', 'social', 'support', '.', 'read', 'our', 'latest', 'report', 'on', 'philanthropy', '.', 'urlplaceholder']
#
# RT WSJ Wealth Report Tax Revenue From the Rich Can Be Hazardous to State Health http://ow.ly/1ebsSX
# ['rt', 'wsj', 'wealth', 'report', 'tax', 'revenue', 'from', 'the', 'rich', 'can', 'be', 'hazardous', 'to', 'state', 'health', 'urlplaceholder']
#
# Are you an emotional trader? Report looks at personality dimensions to understand investment behaviour #WealthInsights http://owl.li/5cZTY
# ['are', 'you', 'an', 'emotional', 'trader', '?', 'report', 'look', 'at', 'personality', 'dimension', 'to', 'understand', 'investment', 'behaviour', '#', 'wealthinsights', 'urlplaceholder']
#
# Barclays Wealth continues to recommend equities, particularly developed markets. http://ow.ly/4N0Y6
# ['barclays', 'wealth', 'continues', 'to', 'recommend', 'equity', ',', 'particularly', 'developed', 'market', '.', 'urlplaceholder']
#
# Barclays Wealth Mgmt CIO Aaron Gurwitz says safe-haven appeal of cash is falling as world economy grows. http://ow.ly/3RHMg
# ['barclays', 'wealth', 'mgmt', 'cio', 'aaron', 'gurwitz', 'say', 'safe-haven', 'appeal', 'of', 'cash', 'is', 'falling', 'a', 'world', 'economy', 'grows', '.', 'urlplaceholder']
#
# Barclays Wealth Jersey Community Awards winners announced at presentation. http://ow.ly/33Eai
# ['barclays', 'wealth', 'jersey', 'community', 'awards', 'winner', 'announced', 'at', 'presentation', '.', 'urlplaceholder']
#
# RT @WSJWealthReport The Biggest, Richest Party Ever - The developed world is struggling to emerge from recession and... http://ow.ly/19EfJp
# ['rt', '@', 'wsjwealthreport', 'the', 'biggest', ',', 'richest', 'party', 'ever', '-', 'the', 'developed', 'world', 'is', 'struggling', 'to', 'emerge', 'from', 'recession', 'and', '...', 'urlplaceholder']
#
# RT @WSJWealthReport Why Women Are More Charitable Than Men - The public face of philanthropy today is predominately ... http://ow.ly/19AcxS
# ['rt', '@', 'wsjwealthreport', 'why', 'women', 'are', 'more', 'charitable', 'than', 'men', '-', 'the', 'public', 'face', 'of', 'philanthropy', 'today', 'is', 'predominately', '...', 'urlplaceholder']
#
# Sumitomo Mitsui Banking Corp., Barclays Wealth & Nikko Cordial Securities Inc. announce private banking joint venture. http://ow.ly/25FOZ
# ['sumitomo', 'mitsui', 'banking', 'corp.', ',', 'barclays', 'wealth', '&', 'nikko', 'cordial', 'securities', 'inc.', 'announce', 'private', 'banking', 'joint', 'venture', '.', 'urlplaceholder']
#
# Gold looks very expensive right now, says Brian Nick http://ow.ly/1cOeJ
# ['gold', 'look', 'very', 'expensive', 'right', 'now', ',', 'say', 'brian', 'nick', 'urlplaceholder']
#
# Barclays Wealth predicts increase in M&A activity. http://su.pr/3JBFth
# ['barclays', 'wealth', 'predicts', 'increase', 'in', 'm', '&', 'a', 'activity', '.', 'urlplaceholder']
#
# Barclays Premier League Trophy wows local football fans - Isle of Man children given the opportunity to see the leg... http://ow.ly/1662Vj
# ['barclays', 'premier', 'league', 'trophy', 'wow', 'local', 'football', 'fan', '-', 'isle', 'of', 'man', 'child', 'given', 'the', 'opportunity', 'to', 'see', 'the', 'leg', '...', 'urlplaceholder']
#
# RT @WSJWealthReport The New Flagship for Philanthropy - Richistan is about to get a new flagship. Construction is a... http://ow.ly/1661Rb
# ['rt', '@', 'wsjwealthreport', 'the', 'new', 'flagship', 'for', 'philanthropy', '-', 'richistan', 'is', 'about', 'to', 'get', 'a', 'new', 'flagship', '.', 'construction', 'is', 'a', '...', 'urlplaceholder']
#
# Five #charities win big at our Community Awards in Jersey, Channel Islands http://ow.ly/HMfp
# ['five', '#', 'charity', 'win', 'big', 'at', 'our', 'community', 'awards', 'in', 'jersey', ',', 'channel', 'islands', 'urlplaceholder']
#
# In times of trouble, banks find customers do not want to let it be http://ow.ly/HxoZ #philanthropy
# ['in', 'time', 'of', 'trouble', ',', 'bank', 'find', 'customer', 'do', 'not', 'want', 'to', 'let', 'it', 'be', 'urlplaceholder', '#', 'philanthropy']
#
# We sponsored 'Stars in their Eyes' on the Isle of Man to raise money for Rebecca House, the IslandÛªs childrenÛªs hospice http://ow.ly/HjLM
# ['we', 'sponsored', "'stars", 'in', 'their', 'eyes', "'", 'on', 'the', 'isle', 'of', 'man', 'to', 'raise', 'money', 'for', 'rebecca', 'house', ',', 'the', 'island\x89ûªs', 'children\x89ûªs', 'hospice', 'urlplaceholder']
#
# Global markets are functioning normally, and stocks, particularly those in developed markets, likely offer more upside http://ow.ly/z55P
# ['global', 'market', 'are', 'functioning', 'normally', ',', 'and', 'stock', ',', 'particularly', 'those', 'in', 'developed', 'market', ',', 'likely', 'offer', 'more', 'upside', 'urlplaceholder']
#
# Barclays Wealth Jersey launches annual Community Awardshttp://su.pr/4dJzIl
# ['barclays', 'wealth', 'jersey', 'launch', 'annual', 'community', 'awardsurlplaceholder']
#
# Opalesque:Barclays Wealth and Ledbury Research report: A new breed of wealthy philanthropists is emerging  http://bit.ly/cnNzP
# ['opalesque', ':', 'barclays', 'wealth', 'and', 'ledbury', 'research', 'report', ':', 'a', 'new', 'breed', 'of', 'wealthy', 'philanthropist', 'is', 'emerging', 'urlplaceholder']
#
# Wealthy becoming increasingly active philanthropists despite downturn http://bit.ly/jgFqG
# ['wealthy', 'becoming', 'increasingly', 'active', 'philanthropist', 'despite', 'downturn', 'urlplaceholder']
#
# JobsGoPublic: Philanthropists Ûmaintaining donationsÛ  http://bit.ly/xHqKL
# ['jobsgopublic', ':', 'philanthropists', '\x89û\x9dmaintaining', 'donations\x89û\x9d', 'urlplaceholder']
#
# Barclays Wealth white paper 'Tomorrow's Philanthropist' launched today. Read the report or watch the video: http://bit.ly/Z0mQ6
# ['barclays', 'wealth', 'white', 'paper', "'tomorrow", "'s", 'philanthropist', "'", 'launched', 'today', '.', 'read', 'the', 'report', 'or', 'watch', 'the', 'video', ':', 'urlplaceholder']
#
# Telegraph: Economic downturn fails to dampen philanthropy  http://bit.ly/4vu2R
# ['telegraph', ':', 'economic', 'downturn', 'fails', 'to', 'dampen', 'philanthropy', 'urlplaceholder']
#
# FT.com: The go-getters become the go-givers - Barclays Wealth's 'Tomorrow's Philanthropist' study reports http://bit.ly/wq6XB
# ['ft.com', ':', 'the', 'go-getter', 'become', 'the', 'go-givers', '-', 'barclays', 'wealth', "'s", "'tomorrow", "'s", 'philanthropist', "'", 'study', 'report', 'urlplaceholder']
#
# Barclays Wealth named Wealth Manager of the Year at the Global Investor Awards
# ['barclays', 'wealth', 'named', 'wealth', 'manager', 'of', 'the', 'year', 'at', 'the', 'global', 'investor', 'awards']
#
# This monthÛªs White Paper explores Barclays new Entrepreneurs Index which maps business activity and wealth creation. http://t.co/8G5wgEcB
# ['this', 'month\x89ûªs', 'white', 'paper', 'explores', 'barclays', 'new', 'entrepreneurs', 'index', 'which', 'map', 'business', 'activity', 'and', 'wealth', 'creation', '.', 'urlplaceholder']
#
# New Barclays report tracks shareholder changes in UK &amp  Ireland businesses as a measure of entrepreneurial activity. http://t.co/bCRKP8Jd
# ['new', 'barclays', 'report', 'track', 'shareholder', 'change', 'in', 'uk', '&', 'amp', 'ireland', 'business', 'a', 'a', 'measure', 'of', 'entrepreneurial', 'activity', '.', 'urlplaceholder']
#
# Û÷What are you like?Ûª Check out this monthÛªs Vanity Fair for a profile of our #BehaviouralFinance team @GregBDavies #VanityFair
# ['\x89û÷what', 'are', 'you', 'like', '?', '\x89ûª', 'check', 'out', 'this', 'month\x89ûªs', 'vanity', 'fair', 'for', 'a', 'profile', 'of', 'our', '#', 'behaviouralfinance', 'team', '@', 'gregbdavies', '#', 'vanityfair']
#
# The US Federal Reserve has confirmed that it will be buying more bonds, so we should too ÛÒ right? Not necessarily. http://t.co/StuqRvLl
# ['the', 'us', 'federal', 'reserve', 'ha', 'confirmed', 'that', 'it', 'will', 'be', 'buying', 'more', 'bond', ',', 'so', 'we', 'should', 'too', '\x89ûò', 'right', '?', 'not', 'necessarily', '.', 'urlplaceholder']
#
# Shaken but not stirred! Government Bonds. WhatÛªs next for the private investorsÛª hero? http://t.co/5M492L8n
# ['shaken', 'but', 'not', 'stirred', '!', 'government', 'bonds', '.', 'what\x89ûªs', 'next', 'for', 'the', 'private', 'investors\x89ûª', 'hero', '?', 'urlplaceholder']
#
# 40 children take part in Disability Football Festival. http://t.co/XSf4Qr7d
# ['40', 'child', 'take', 'part', 'in', 'disability', 'football', 'festival', '.', 'urlplaceholder']
#
# Barclays Wealth is proud to sponsor Shadow Catchers: Camera-less Photography at the Victoria and Albert Museum. http://su.pr/5Vwkqb
# ['barclays', 'wealth', 'is', 'proud', 'to', 'sponsor', 'shadow', 'catchers', ':', 'camera-less', 'photography', 'at', 'the', 'victoria', 'and', 'albert', 'museum', '.', 'urlplaceholder']
#
# RT @WSJEconomy: EU Governments Face Debt Increase http://bit.ly/Z7G2W
# ['rt', '@', 'wsjeconomy', ':', 'eu', 'governments', 'face', 'debt', 'increase', 'urlplaceholder']
#
# RT @WSJEconomy: Japan Trade Surplus Expands http://bit.ly/UqJyl
# ['rt', '@', 'wsjeconomy', ':', 'japan', 'trade', 'surplus', 'expands', 'urlplaceholder']
#
# ...
#
# Our study also suggested that helping to prepare meals increased positive emotion &amp; pride. #HealthyKids http://t.co/CDpS10Byph
# ['our', 'study', 'also', 'suggested', 'that', 'helping', 'to', 'prepare', 'meal', 'increased', 'positive', 'emotion', '&', 'amp', ';', 'pride', '.', '#', 'healthykids', 'urlplaceholder']
#
# Paul Bulcke "Healthier kids perform better at school &amp;are more productive as adults..It's a virtuous circle" http://t.co/LPWX4UHUCt #wef2014
# ['paul', 'bulcke', '``', 'healthier', 'kid', 'perform', 'better', 'at', 'school', '&', 'amp', ';', 'are', 'more', 'productive', 'a', 'adult', '..', 'it', "'s", 'a', 'virtuous', 'circle', "''", 'urlplaceholder', '#', 'wef2014']
#
# Paul Bulcke "Helathier kids are more productive as adults, it's a virtuous circle" #wef2014 #health
# ['paul', 'bulcke', '``', 'helathier', 'kid', 'are', 'more', 'productive', 'a', 'adult', ',', 'it', "'s", 'a', 'virtuous', 'circle', "''", '#', 'wef2014', '#', 'health']
#
# Paul Bulcke "We can't be a healthy business in an unhealthy society" #wef2014 #davos
# ['paul', 'bulcke', '``', 'we', 'ca', "n't", 'be', 'a', 'healthy', 'business', 'in', 'an', 'unhealthy', 'society', "''", '#', 'wef2014', '#', 'davos']
#
# Paul Bulcke "We commit to be being part of the solution" #wef2014 #health
# ['paul', 'bulcke', '``', 'we', 'commit', 'to', 'be', 'being', 'part', 'of', 'the', 'solution', "''", '#', 'wef2014', '#', 'health']
#
# Paul Bulcke "You only give #health some value when you lose it" #wef2014 #davos http://t.co/eutHAhd0El
# ['paul', 'bulcke', '``', 'you', 'only', 'give', '#', 'health', 'some', 'value', 'when', 'you', 'lose', 'it', "''", '#', 'wef2014', '#', 'davos', 'urlplaceholder']
#
# Pfizer CEO Read: @pfizer, @CarterCenter, @ITIAtlanta &amp; partners are working to end trachoma as public health threat by 2020 #trachoma15
# ['pfizer', 'ceo', 'read', ':', '@', 'pfizer', ',', '@', 'cartercenter', ',', '@', 'itiatlanta', '&', 'amp', ';', 'partner', 'are', 'working', 'to', 'end', 'trachoma', 'a', 'public', 'health', 'threat', 'by', '2020', '#', 'trachoma15']
#
# Pfizer Consumer Healthcare is a proud sponsor of World Osteoporosis Day 2013 http://t.co/efAI7vdDfi
# ['pfizer', 'consumer', 'healthcare', 'is', 'a', 'proud', 'sponsor', 'of', 'world', 'osteoporosis', 'day', '2013', 'urlplaceholder']
#
# Pfizer Global Health Fellows &amp; Accordia Global Health Foundation recognize 10 years of improving healthcare in Africa http://t.co/Ov08CTEien
# ['pfizer', 'global', 'health', 'fellows', '&', 'amp', ';', 'accordia', 'global', 'health', 'foundation', 'recognize', '10', 'year', 'of', 'improving', 'healthcare', 'in', 'africa', 'urlplaceholder']
#
# Pfizer R&amp;D President Mikael Dolsten to speak at #ForbesHealth 2013 panel on #DrugResearch http://t.co/7PYELlpGez
# ['pfizer', 'r', '&', 'amp', ';', 'd', 'president', 'mikael', 'dolsten', 'to', 'speak', 'at', '#', 'forbeshealth', '2013', 'panel', 'on', '#', 'drugresearch', 'urlplaceholder']
#
# Pfizer recognized w/  Corporate Leadership Award at @LupusOrg  2013 National Gala #Lupus
# ['pfizer', 'recognized', 'w/', 'corporate', 'leadership', 'award', 'at', '@', 'lupusorg', '2013', 'national', 'gala', '#', 'lupus']
#
# Pfizer VP Jack Watters: Keeping caregivers healthy is key @bbglink #bbglec
# ['pfizer', 'vp', 'jack', 'watters', ':', 'keeping', 'caregiver', 'healthy', 'is', 'key', '@', 'bbglink', '#', 'bbglec']
#
# Pfizer VP Jack Watters: We need life-changing approach to healthy behaviors @bbglink #bbglec
# ['pfizer', 'vp', 'jack', 'watters', ':', 'we', 'need', 'life-changing', 'approach', 'to', 'healthy', 'behavior', '@', 'bbglink', '#', 'bbglec']
#
# PfizerÌ¢âÂã¢s Adele Gulfo @gulfoa on receiving @SpringboardEnt Oracle Award: be open to new paths, I'm a scientist turned business person
# ['pfizerì¢\x89ââ\x89ã¢s', 'adele', 'gulfo', '@', 'gulfoa', 'on', 'receiving', '@', 'springboardent', 'oracle', 'award', ':', 'be', 'open', 'to', 'new', 'path', ',', 'i', "'m", 'a', 'scientist', 'turned', 'business', 'person']
#
# PfizerÌ¢âÂã¢s Adele Gulfo @gulfoa on receiving @SpringboardEnt Oracle Award: Focus on proactive, passionate leadership is key to success
# ['pfizerì¢\x89ââ\x89ã¢s', 'adele', 'gulfo', '@', 'gulfoa', 'on', 'receiving', '@', 'springboardent', 'oracle', 'award', ':', 'focus', 'on', 'proactive', ',', 'passionate', 'leadership', 'is', 'key', 'to', 'success']
#
# Polish teenagers learn to cook balanced meals through our Ì¢âÂÒ Eat Tasty and HealthyÌ¢âÂå programme #SharedValue http://t.co/m36clDfPtC
# ['polish', 'teenager', 'learn', 'to', 'cook', 'balanced', 'meal', 'through', 'our', 'ì¢\x89ââ\x81ò', 'eat', 'tasty', 'and', 'healthyì¢\x89ââå\x9d', 'programme', '#', 'sharedvalue', 'urlplaceholder']
#
# Prof Bhutta "We need to link our agriculture and food systems holistically." #NINS2013
# ['prof', 'bhutta', '``', 'we', 'need', 'to', 'link', 'our', 'agriculture', 'and', 'food', 'system', 'holistically', '.', "''", '#', 'nins2013']
#
# Prof Bray "We seem to respond to beverages with calories in a different way to foods." #NINS2013
# ['prof', 'bray', '``', 'we', 'seem', 'to', 'respond', 'to', 'beverage', 'with', 'calorie', 'in', 'a', 'different', 'way', 'to', 'food', '.', "''", '#', 'nins2013']
#
# Protect the environment and your health now &amp; in the future by making Ì¢âÂÒgreenÌ¢âÂå holiday choices this season. See tips: http://t.co/CdrMjrgV3J
# ['protect', 'the', 'environment', 'and', 'your', 'health', 'now', '&', 'amp', ';', 'in', 'the', 'future', 'by', 'making', 'ì¢\x89ââ\x81ògreenì¢\x89ââå\x9d', 'holiday', 'choice', 'this', 'season', '.', 'see', 'tip', ':', 'urlplaceholder']
#
# Proud to be awarded Ì¢âÂÒBest Bank in ChinaÌ¢âÂå at The Asset Triple A Country Awards for 7th year in row: http://t.co/5Rpow77RcG #APAC #leadership
# ['proud', 'to', 'be', 'awarded', 'ì¢\x89ââ\x81òbest', 'bank', 'in', 'chinaì¢\x89ââå\x9d', 'at', 'the', 'asset', 'triple', 'a', 'country', 'awards', 'for', '7th', 'year', 'in', 'row', ':', 'urlplaceholder', '#', 'apac', '#', 'leadership']
#
# Proud to receive @ENERGYSTAR 2014 Partner of the Year - Sustained Excellence Award! Honored by @EPA for 9th yr: http://t.co/HzsaT8vRSA
# ['proud', 'to', 'receive', '@', 'energystar', '2014', 'partner', 'of', 'the', 'year', '-', 'sustained', 'excellence', 'award', '!', 'honored', 'by', '@', 'epa', 'for', '9th', 'yr', ':', 'urlplaceholder']
#
# Sarihusada Wins 3 GKPM Awards 2013, an appreciation given by The Coordinating Ministry of Social Welfare &amp; CFCD #danone #Indonesia
# ['sarihusada', 'wins', '3', 'gkpm', 'awards', '2013', ',', 'an', 'appreciation', 'given', 'by', 'the', 'coordinating', 'ministry', 'of', 'social', 'welfare', '&', 'amp', ';', 'cfcd', '#', 'danone', '#', 'indonesia']
#
# See how easy it is to cook #healthy fire-roasted corn salad w/ grilled chicken from celebrity @ChefArtSmith: http://t.co/4Z9YgCfr2z
# ['see', 'how', 'easy', 'it', 'is', 'to', 'cook', '#', 'healthy', 'fire-roasted', 'corn', 'salad', 'w/', 'grilled', 'chicken', 'from', 'celebrity', '@', 'chefartsmith', ':', 'urlplaceholder']
#
# See the faces of people touched by our #MerckforMothers maternal health programs in the U.S: http://t.co/SpQUZhYjjl
# ['see', 'the', 'face', 'of', 'people', 'touched', 'by', 'our', '#', 'merckformothers', 'maternal', 'health', 'program', 'in', 'the', 'u.s', ':', 'urlplaceholder']
#
# Small tweaks with big social impact! See how the @SASDIAlliance upgrades #CapeTownÌ¢âÂã¢s informal housing: http://t.co/cMroj0eQgI #FTCitiAwards
# ['small', 'tweak', 'with', 'big', 'social', 'impact', '!', 'see', 'how', 'the', '@', 'sasdialliance', 'upgrade', '#', 'capetownì¢\x89ââ\x89ã¢s', 'informal', 'housing', ':', 'urlplaceholder', '#', 'ftcitiawards']
#
# Steven Heymsfield: "Chronic non-communicable disease is the major health problem of the day" #NINS2013
# ['steven', 'heymsfield', ':', '``', 'chronic', 'non-communicable', 'disease', 'is', 'the', 'major', 'health', 'problem', 'of', 'the', 'day', "''", '#', 'nins2013']
#
# Sticking your thumb out for a ride is long gone. See how @BlaBlaCarUK encourages digital #hitchhiking: http://t.co/IaD8iI9uYl #FTCitiAwards
# ['sticking', 'your', 'thumb', 'out', 'for', 'a', 'ride', 'is', 'long', 'gone', '.', 'see', 'how', '@', 'blablacaruk', 'encourages', 'digital', '#', 'hitchhiking', ':', 'urlplaceholder', '#', 'ftcitiawards']
#
# Study could smooth lumps from powdered drinks: http://t.co/ZYHtV8AowD  #GoodFoodGoodLife http://t.co/qmwqoY3GLZ
# ['study', 'could', 'smooth', 'lump', 'from', 'powdered', 'drink', ':', 'urlplaceholder', '#', 'goodfoodgoodlife', 'urlplaceholder']
#
# Study: "Children cooking with a parent ate more overall of their meal..." #HealthyKids
# ['study', ':', '``', 'children', 'cooking', 'with', 'a', 'parent', 'ate', 'more', 'overall', 'of', 'their', 'meal', '...', "''", '#', 'healthykids']
#
# The @UNCF Ì¢âÂå¢ Merck Science Initiative annually awards scholarships/fellowships to top science scholars. Apply for 2014 http://t.co/7Ai8U6kekZ
# ['the', '@', 'uncf', 'ì¢\x89ââå¢', 'merck', 'science', 'initiative', 'annually', 'award', 'scholarships/fellowships', 'to', 'top', 'science', 'scholar', '.', 'apply', 'for', '2014', 'urlplaceholder']
#
# The #HealthyKidsQuest offers teachers free educational material to use with students: http://t.co/echwusSsIt @AgMuseum
# ['the', '#', 'healthykidsquest', 'offer', 'teacher', 'free', 'educational', 'material', 'to', 'use', 'with', 'student', ':', 'urlplaceholder', '@', 'agmuseum']
#
# The big moment has arrived! #FTCitiAwards winners will be announced tonight at 9PM EST! Learn more: http://t.co/gYsI2r3SYy #progressmakers
# ['the', 'big', 'moment', 'ha', 'arrived', '!', '#', 'ftcitiawards', 'winner', 'will', 'be', 'announced', 'tonight', 'at', '9pm', 'est', '!', 'learn', 'more', ':', 'urlplaceholder', '#', 'progressmakers']
#
# The H4HInitiative develops strategies to encourage patients &amp; people to adopt healthier #hydration practices http://t.co/t6zBUmoy78
# ['the', 'h4hinitiative', 'develops', 'strategy', 'to', 'encourage', 'patient', '&', 'amp', ';', 'people', 'to', 'adopt', 'healthier', '#', 'hydration', 'practice', 'urlplaceholder']
#
# The International Osteoporosis Foundation @iofbonehealth has rewarded #Danone for its program to sensitize employees to #bonehealth
# ['the', 'international', 'osteoporosis', 'foundation', '@', 'iofbonehealth', 'ha', 'rewarded', '#', 'danone', 'for', 'it', 'program', 'to', 'sensitize', 'employee', 'to', '#', 'bonehealth']
#
# The World Wide Web is 25 today &amp; going strong; must be those healthy living sites like http://t.co/9pm9a8xxZp in its system! #web25 #bewell
# ['the', 'world', 'wide', 'web', 'is', '25', 'today', '&', 'amp', ';', 'going', 'strong', ';', 'must', 'be', 'those', 'healthy', 'living', 'site', 'like', 'urlplaceholder', 'in', 'it', 'system', '!', '#', 'web25', '#', 'bewell']
#
# This Heart Health Month, Million Hearts begins with you! Check out this infographic to learn more: http://t.co/rBBkjswIQh
# ['this', 'heart', 'health', 'month', ',', 'million', 'hearts', 'begin', 'with', 'you', '!', 'check', 'out', 'this', 'infographic', 'to', 'learn', 'more', ':', 'urlplaceholder']
#
# This week is @sleepfoundationÌ¢âÂã¢s Sleep Awareness Week to spotlight health benefits of sleep. Trouble sleeping? Visit: http://t.co/SjpJ4afZiK
# ['this', 'week', 'is', '@', 'sleepfoundationì¢\x89ââ\x89ã¢s', 'sleep', 'awareness', 'week', 'to', 'spotlight', 'health', 'benefit', 'of', 'sleep', '.', 'trouble', 'sleeping', '?', 'visit', ':', 'urlplaceholder']
#
# To celebrate Global Community Day over 400 #CitiVolunteers in #Spain are collaborating w food banks, animal shelters, &amp; childrenÌ¢âÂã¢s hospitals
# ['to', 'celebrate', 'global', 'community', 'day', 'over', '400', '#', 'citivolunteers', 'in', '#', 'spain', 'are', 'collaborating', 'w', 'food', 'bank', ',', 'animal', 'shelter', ',', '&', 'amp', ';', 'childrenì¢\x89ââ\x89ã¢s', 'hospital']
#
# Today is International Maternal Health Day. RT if you agree that no woman should die giving life #IntlMHDay #MerckforMothers
# ['today', 'is', 'international', 'maternal', 'health', 'day', '.', 'rt', 'if', 'you', 'agree', 'that', 'no', 'woman', 'should', 'die', 'giving', 'life', '#', 'intlmhday', '#', 'merckformothers']
#
# Today, the Health Ministry rewarded Danone Spain for its work in the Social School for Women Empowerment http://t.co/REnQObAviY #EndVAW
# ['today', ',', 'the', 'health', 'ministry', 'rewarded', 'danone', 'spain', 'for', 'it', 'work', 'in', 'the', 'social', 'school', 'for', 'women', 'empowerment', 'urlplaceholder', '#', 'endvaw']
#
# Turning waste into gold! See how @sanergy solves 1 of Nairobi's major urban problems: http://t.co/mJJQ4REanv  #FTCitiAwards #progressmakers
# ['turning', 'waste', 'into', 'gold', '!', 'see', 'how', '@', 'sanergy', 'solves', '1', 'of', 'nairobi', "'s", 'major', 'urban', 'problem', ':', 'urlplaceholder', '#', 'ftcitiawards', '#', 'progressmakers']
#
# Want to improve your health? Read about the importance of following your prescribed treatment plan: http://t.co/KwKWhWSGPL
# ['want', 'to', 'improve', 'your', 'health', '?', 'read', 'about', 'the', 'importance', 'of', 'following', 'your', 'prescribed', 'treatment', 'plan', ':', 'urlplaceholder']
#
# Watch celebrity @ChefArtSmith cook up his #healthy stewed white beans &amp; greens: http://t.co/mTXxzecieu
# ['watch', 'celebrity', '@', 'chefartsmith', 'cook', 'up', 'his', '#', 'healthy', 'stewed', 'white', 'bean', '&', 'amp', ';', 'green', ':', 'urlplaceholder']
#
# Watch the moving story of @Parinaam assisting the poor w/ support that will help them for a lifetime: http://t.co/qrwrDjslxb #FTCitiAwards
# ['watch', 'the', 'moving', 'story', 'of', '@', 'parinaam', 'assisting', 'the', 'poor', 'w/', 'support', 'that', 'will', 'help', 'them', 'for', 'a', 'lifetime', ':', 'urlplaceholder', '#', 'ftcitiawards']
#
# We pledge to accelerate #salt reduction in all our food brands worldwide http://t.co/xllA3Z1fSA http://t.co/NqPQGIEM9g
# ['we', 'pledge', 'to', 'accelerate', '#', 'salt', 'reduction', 'in', 'all', 'our', 'food', 'brand', 'worldwide', 'urlplaceholder', 'urlplaceholder']
#
# We think it's a shame "Cake to Bake" didn't make it through. #Eurovision #GoodFoodGoodLife
# ['we', 'think', 'it', "'s", 'a', 'shame', '``', 'cake', 'to', 'bake', "''", 'did', "n't", 'make', 'it', 'through', '.', '#', 'eurovision', '#', 'goodfoodgoodlife']
#
# We're grateful for 2x honors @ChamberBCLC Citizens AwardsÌ¢âÂÛÏ working to empower students &amp; communities around the world http://t.co/NQAn2VWdmf
# ['we', "'re", 'grateful', 'for', '2x', 'honor', '@', 'chamberbclc', 'citizens', 'awardsì¢\x89ââ\x89ûï', 'working', 'to', 'empower', 'student', '&', 'amp', ';', 'community', 'around', 'the', 'world', 'urlplaceholder']
#
# WeÌ¢âÂã¢re the 1. to sign up to a European initiative to increase fairness in the food supply chain http://t.co/So5WZdpuBD http://t.co/o9u8tzYrRR
# ['weì¢\x89ââ\x89ã¢re', 'the', '1.', 'to', 'sign', 'up', 'to', 'a', 'european', 'initiative', 'to', 'increase', 'fairness', 'in', 'the', 'food', 'supply', 'chain', 'urlplaceholder', 'urlplaceholder']
#
# WeÌ¢âÂã¢re working hard to do all we can to promote healthier lifestyles and diets for kids http://t.co/hw8oIHYMaI
# ['weì¢\x89ââ\x89ã¢re', 'working', 'hard', 'to', 'do', 'all', 'we', 'can', 'to', 'promote', 'healthier', 'lifestyle', 'and', 'diet', 'for', 'kid', 'urlplaceholder']
#
# Yesterday, these #HealthyKids lit up Broadway with #Nestle, @iaaforg and some sporting stars: http://t.co/YdtBj60Ofz
# ['yesterday', ',', 'these', '#', 'healthykids', 'lit', 'up', 'broadway', 'with', '#', 'nestle', ',', '@', 'iaaforg', 'and', 'some', 'sporting', 'star', ':', 'urlplaceholder']
#
# Z Bhutta: Problems with food&amp;land systems include land acquistion, commodity speculation affecting food prices&amp;lack of discussion #NINS2013
# ['z', 'bhutta', ':', 'problems', 'with', 'food', '&', 'amp', ';', 'land', 'system', 'include', 'land', 'acquistion', ',', 'commodity', 'speculation', 'affecting', 'food', 'price', '&', 'amp', ';', 'lack', 'of', 'discussion', '#', 'nins2013']
